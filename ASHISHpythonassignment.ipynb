# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np  
import csv

# %%
import os
os.chdir('C:/Users/ASHISH/Desktop/PYTHON/Movielens Project')

# %%
movies_df = pd.read_table('movies.dat',sep="::",header = None,index_col=None)
ratings_df = pd.read_table('ratings.dat',sep="::",header = None,index_col=None)
users_df = pd.read_table('users.dat',sep="::",header = None,index_col=None)
# Out:
# C:\Users\ASHISH\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# C:\Users\ASHISH\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# C:\Users\ASHISH\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# ...

# %%
movies_df.columns = ('MovieID','Title','Genre')

# %%
movies_df
# Out:
#       MovieID                                              Title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# 5           6                                        Heat (1995)
# 6           7                                     Sabrina (1995)
# 7           8                                Tom and Huck (1995)
# 8           9                                Sudden Death (1995)
# 9          10                                   GoldenEye (1995)
# 10         11                     American President, The (1995)
# 11         12                 Dracula: Dead and Loving It (1995)
# 12         13                                       Balto (1995)
# ...

# %%
ratings_df.columns = ('UserID','MovieID','MovieRating','Timestamp')

# %%
users_df.columns = ('MovieID','Gender','Age','Num','ZIP')

# %%
users_df.head()
# Out:
#    MovieID Gender  Age  Num    ZIP
# 0        1      F    1   10  48067
# 1        2      M   56   16  70072
# 2        3      M   25   15  55117
# 3        4      M   45    7  02460
# 4        5      M   25   20  55455

# %%
movies_df.head()
# Out:
#    MovieID                               Title                         Genre
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
ratings_df.head()
# Out:
#    UserID  MovieID  MovieRating  Timestamp
# 0       1     1193            5  978300760
# 1       1      661            3  978302109
# 2       1      914            3  978301968
# 3       1     3408            4  978300275
# 4       1     2355            5  978824291

# %%
users_df.head()
# Out:
#    MovieID Gender  Age  Num    ZIP
# 0        1      F    1   10  48067
# 1        2      M   56   16  70072
# 2        3      M   25   15  55117
# 3        4      M   45    7  02460
# 4        5      M   25   20  55455

# %%
#(1)Number of movies, Number of ratings and Number users_who_rated (12 Marks)
total_rows=len(movies_df.axes[0])
total_rows  #no.of movies
# Out:
# 3883

# %%
ratings_df.MovieRating.value_counts() #no.of ratings
# Out:
# 4    348971
# 3    261197
# 5    226310
# 2    107557
# 1     56174
# Name: MovieRating, dtype: int64

# %%
total_rows=len(users_df.axes[0])
total_rows   #total no.of users who rated
# Out:
# 6040

# %%
#(2)5-point summary of the rating attribute (12 Marks)
ratings_df.MovieRating.describe()
# Out:
# count    1.000209e+06
# mean     3.581564e+00
# std      1.117102e+00
# min      1.000000e+00
# 25%      3.000000e+00
# 50%      4.000000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: MovieRating, dtype: float64

# %%
#(2)5-point summary of the rating attribute (12 Marks)
print('Min Rating : {0}'.format(ratings_df.MovieRating.min())) # minimum
print('Max Rating : {0}'.format(ratings_df.MovieRating.max())) #maximum
print('25% Rating Q1 : {0}'.format(ratings_df.MovieRating.quantile(.25))) # 25 percentile
print('50% Rating Q2: {0}'.format(ratings_df.MovieRating.quantile(.5))) # 50 percentile
print('75% Rating Q3: {0}'.format(ratings_df.MovieRating.quantile(.75))) # 75 percetile
# Out:
# Min Rating : 1
# Max Rating : 5
# 25% Rating Q1 : 3.0
# 50% Rating Q2: 4.0
# 75% Rating Q3: 4.0

# %%
#(3)Rating distribution as a histogram (12 Marks)
ratings_df.MovieRating.plot(kind='hist',rot = 0,title = 'Rating in HISOGRAM plot')

# %%
movies_df.Genre.value_counts()
# Out:
# Drama                                       843
# Comedy                                      521
# Horror                                      178
# Comedy|Drama                                162
# Comedy|Romance                              142
# Drama|Romance                               134
# Documentary                                 116
# Thriller                                    101
# Action                                       65
# Drama|Thriller                               63
# Action|Thriller                              48
# Children's|Comedy                            47
# Crime|Drama                                  44
# Drama|War                                    43
# Romance                                      40
# Action|Drama                                 39
# Animation|Children's                         35
# Comedy|Drama|Romance                         34
# Horror|Sci-Fi                                33
# Western                                      33
# ...

# %%
#(4)Genre distribution as a pie chart (12 Marks)
movies_df.Genre.value_counts(sort=True).plot.pie()
plt.show()

# %%
movies_df.Genre.value_counts(sort=False).plot.pie()
plt.show()

# %%
movies_df.Genre.str.split('|', 4, expand=True).
# Out:
#   File "<ipython-input-22-f5896b67d7b4>", line 1
#     movies_df.Genre.str.split('|', 4, expand=True).
#                                                     ^
# SyntaxError: invalid syntax

# %%
top = movielens.groupby(movielens['title']).count()
type(top)
top1=top[['rating']]
top_movies=topp.sort_values('Rating',ascending = False)
top_movies.columns=["rating_count"]
top_movies.head(50)
top_movies.loc[top_movies.rating]

# %%
top = movies_df.groupby(movies_df['Title']).count()
top1= top[['MovieRating']]
top_movies=top1.sort_values('MovieRating',ascending = False)
top_movies.columns=["rating_count"]
top_movies.head(50)
top_movies.loc[top_movies.rating]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-6d672a6d31eb> in <module>()
#       1 top = movies_df.groupby(movies_df['Title']).count()
# ----> 2 top1= top[['MovieRating']]
#       3 top_movies=top1.sort_values('MovieRating',ascending = False)
#       4 top_movies.columns=["rating_count"]
#       5 top_movies.head(50)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# ...

# %%
top

# %%
movielens = pd.concat[['movies_df','ratings_df']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-59a160c1ce71> in <module>()
# ----> 1 movielens = pd.concat[['movies_df','ratings_df']]
#
# TypeError: 'function' object is not subscriptable

# %%
#(5)Top ranked movies consider only those movies which have received at-least 100 ratings (12 Marks)
movie_lens_df = pd.concat((movies_df, ratings_df))
# Out:
# C:\Users\ASHISH\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
movie_lens_df.head()
# Out:
#                           Genre  MovieID  MovieRating  Timestamp  \
# 0   Animation|Children's|Comedy        1          NaN        NaN
# 1  Adventure|Children's|Fantasy        2          NaN        NaN
# 2                Comedy|Romance        3          NaN        NaN
# 3                  Comedy|Drama        4          NaN        NaN
# 4                        Comedy        5          NaN        NaN
#
#                                 Title  UserID
# 0                    Toy Story (1995)     NaN
# 1                      Jumanji (1995)     NaN
# 2             Grumpier Old Men (1995)     NaN
# 3            Waiting to Exhale (1995)     NaN
# 4  Father of the Bride Part II (1995)     NaN

# %%
ratings_df.head()
# Out:
#    UserID  MovieID  MovieRating  Timestamp
# 0       1     1193            5  978300760
# 1       1      661            3  978302109
# 2       1      914            3  978301968
# 3       1     3408            4  978300275
# 4       1     2355            5  978824291

# %%
ratings_df
# Out:
#          UserID  MovieID  MovieRating  Timestamp
# 0             1     1193            5  978300760
# 1             1      661            3  978302109
# 2             1      914            3  978301968
# 3             1     3408            4  978300275
# 4             1     2355            5  978824291
# 5             1     1197            3  978302268
# 6             1     1287            5  978302039
# 7             1     2804            5  978300719
# 8             1      594            4  978302268
# 9             1      919            4  978301368
# 10            1      595            5  978824268
# 11            1      938            4  978301752
# 12            1     2398            4  978302281
# 13            1     2918            4  978302124
# 14            1     1035            5  978301753
# 15            1     2791            4  978302188
# 16            1     2687            3  978824268
# 17            1     2018            4  978301777
# ...

# %%
ratings_df.MovieRating.count()
# Out:
# 1000209

# %%
ratings_df(MovieRating.count>100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-8689b5c8d4f7> in <module>()
# ----> 1 ratings_df(MovieRating.count>100)
#
# NameError: name 'MovieRating' is not defined

# %%
ratings_df[ratings_df.MovieRating.count(100)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-5061c6ec6a57> in <module>()
# ----> 1 ratings_df[ratings_df.MovieRating.count(100)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in count(self, level)
#    1421             level = self.index._get_level_number(level)
#    1422
# -> 1423         lev = self.index.levels[level]
#    1424         lab = np.array(self.index.labels[level], subok=False, copy=True)
#    1425
#
# AttributeError: 'RangeIndex' object has no attribute 'levels'
